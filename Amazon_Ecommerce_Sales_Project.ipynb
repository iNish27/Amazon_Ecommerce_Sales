# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Nishs\Downloads\New Dataset\Amazon Sale Report.csv")
df
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\2793765135.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Nishs\Downloads\New Dataset\Amazon Sale Report.csv")
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# ...

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df = df.drop(columns=["B2B", "Unnamed: 22"])

# %%
df["Courier Status"].fillna(df["Courier Status"].mode()[0], inplace=True)

df["currency"].fillna(df["currency"].mode()[0], inplace=True)

df["Amount"].fillna(df["Amount"].mode()[0], inplace=True)

df["ship-city"].fillna(df["ship-city"].mode()[0], inplace=True)

df["ship-state"].fillna(df["ship-state"].mode()[0], inplace=True)

df["ship-postal-code"].fillna(df["ship-postal-code"].mode()[0], inplace=True)

df["ship-country"].fillna(df["ship-country"].mode()[0], inplace=True)

df["promotion-ids"].fillna(df["promotion-ids"].mode()[0], inplace=True)

df["fulfilled-by"].fillna(df["fulfilled-by"].mode()[0], inplace=True)
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Courier Status"].fillna(df["Courier Status"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isna().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# fulfilled-by          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Best Selling Categories

# %%
Best_Selling_Categories = df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
print(Best_Selling_Categories.head())
# Out:
# Category
# Set              40497682.03
# kurta            22560386.70
# Western Dress    11533676.69
# Top               5530135.30
# Ethnic Dress       817551.66
# Name: Amount, dtype: float64

# %% [markdown]
# # Best Selling Categories by date

# %%
df["Date"] = df["Date"]
sales_Date = df.groupby("Date")["Amount"].sum()
print(sales_Date)
# Out:
# Date
# 03-31-22     105274.85
# 04-01-22     908570.60
# 04-02-22     952602.53
# 04-03-22    1051264.38
# 04-04-22     918368.17
#                ...
# 06-25-22     678972.58
# 06-26-22     795156.02
# 06-27-22     736468.67
# 06-28-22     802409.53
# 06-29-22     423101.76
# Name: Amount, Length: 91, dtype: float64

# %% [markdown]
# # Best Selling Category by City

# %%
City_Sales = df.groupby("ship-city")["Amount"].sum().sort_values(ascending=False)
print(City_Sales.head(10))
# Out:
# ship-city
# BENGALURU    7081401.99
# HYDERABAD    5132764.82
# MUMBAI       3807802.80
# NEW DELHI    3751529.78
# CHENNAI      3214854.74
# PUNE         2418318.18
# KOLKATA      1469242.87
# GURUGRAM     1255533.74
# THANE        1041861.29
# LUCKNOW       975422.34
# Name: Amount, dtype: float64

# %% [markdown]
# # Bar chart for Monthly Sales

# %%
import matplotlib.pyplot as plt
import pandas as pd

df.columns = df.columns.str.strip()
df['Date'] = pd.to_datetime(df['Date'])

monthly_sales = df.groupby(pd.Grouper(key='Date', freq='ME'))['Amount'].sum().reset_index()


plt.figure(figsize=(14, 6))
plt.bar(monthly_sales["Date"], monthly_sales["Amount"], color = "#73361C")
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\3614364804.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# # Best Selling Products

# %% [markdown]
# ### Line plot for sales

# %%
plt.Figure(figsize=(14, 6))
plt.plot(monthly_sales['Date'], monthly_sales['Amount'], 
         marker = 'o', linestyle = '-', color = "#73361C")
plt.title("Monthly Sales trend")
plt.xlabel("Month")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sales according to status

# %%
status_counts = df["Status"].value_counts()

plt.figure(figsize=(8, 6))
status_counts.plot(kind = 'bar', color = "#73361C")
plt.title("Order count by status")
plt.xlabel("Status")
plt.ylabel("Number of Orders")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sales according to city only top 10 cities

# %%
top_cities = df['ship-city'].value_counts().nlargest(10)

# %%
colors = ['#73361C', '#8C4A2F', '#A56242', '#BD7B56', '#D6936A',
          '#E7AE8A', '#F2C3A6', '#F6D2B8', '#FBE2CB', '#FFF0DE']


plt.Figure(figsize=(10,4))
plt.pie(top_cities,
        labels = top_cities.index,
        autopct = '%1.1f%%',
        startangle = 140,
        colors= colors)

plt.title("Top 10 Shipping Cities by Order Count")
plt.tight_layout()
plt.show()

# %%
Best_Selling_Categories.plot(
    kind = "bar",
    figsize = (10, 5),
    color = "#73361C",
    title = "Best Selling Categories",
    xlabel = "Category",
    ylabel = "Amount",
    )

plt.xticks(rotation = 0)
plt.tight_layout()
plt.show()

# %%
best_selling = df.groupby("Style")["Qty"].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# # Top selling products by sku & style

# %%
best_selling.plot(kind = "bar",
                  title = 'Top Selling Products (by Style)',
                  xlabel = 'Style',
                  ylabel = 'Quantity Sold',
                  color = "#73361C")
# Out:
# <Axes: title={'center': 'Top Selling Products (by Style)'}, xlabel='Style', ylabel='Quantity Sold'>

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Amount'], bins = 20, kde = True,color = "#73361C")
plt.xlabel('Amount')
plt.ylabel('Distribution')
plt.title('histplot of Amount')
plt.show()

# %%
Q1 = df['Amount'].quantile(0.25)
Q3 = df['Amount'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df['Amount'] = df['Amount'].clip(lower=lower_bound, upper=upper_bound)

# %%
plt.figure (figsize=(10, 5))
sns.histplot(df['Amount'], bins = 20, kde = True,color = "#73361C")
plt.xlabel('Amount')
plt.ylabel('Distribution')
plt.title('histplot of Amount')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['ship-postal-code'], bins = 20, kde = True,color = "#73361C")
plt.xlabel('ship-postal-code')
plt.ylabel('Distribution')
plt.title('histplot of ship-postal-code')
plt.show()

# %%
plt.figure(figsize= (10, 4))
sns.boxplot(x=df['Amount'], color = "#73361C")
plt.xlabel('Amount')
plt.title('Boxplot of Amount')
plt.show()

# %% [markdown]
# # violinplot to show distribution and density

# %%
plt.figure(figsize=(10, 4))
sns.violinplot(x=df["Amount"], color="#73361C")
plt.title("Violin Plot of Amount")
plt.xlabel("Amount")
plt.show()

# %% [markdown]
# # Density plot to show density of amount

# %%
plt.figure(figsize = (10, 4))
sns.kdeplot(df['Amount'], fill = True, color = "#73361C")
plt.title('Density plot of Amount')
plt.xlabel('Amount')
plt.ylabel('Density')
plt.show()

# %%
plt.Figure(figsize=(10, 4))
sns.kdeplot(df['ship-postal-code'], fill = True, color = "#73361C")
plt.title("Densirty plot of Amount")
plt.xlabel("ship-postal-code")
plt.ylabel("Density")
plt.show()

# %%
plt.Figure(figsize=(10, 4))
sns.histplot(data=df, x = 'Amount', hue='Category', bins = 20, kde=True, palette = "BrBG")
plt.title('Histogram of Amount by Category')
plt.xlabel('Amount')
plt.ylabel('Count')
plt.legend(title = 'Category')
plt.show()
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\363568057.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title = 'Category')

# %%
numeric_df = df.select_dtypes(include = ['number'])
corr = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot = True, cmap = 'BrBG', fmt=".2f", linewidths=0.5)
plt.title("Heatmap of Numerical Features", fontsize="20")
plt.show()

# %%
# %pip install pgeocode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pgeocode

# %%
#initialize pgeocode with country for India
geocode = pgeocode.Nominatim('IN')

# %%
# function to get coordinates

def get_coordinates(postal_code):
    try:
        results = geocode.query_postal_code(postal_code)
        return pd.Series([results.latitude, results.longitude], index=['latitude', 'longitude'])
    except Exception as e:
        print(f'Error for postal code {postal_code}: {e}')
        return pd.Series([None, None], index=['latitude', 'longitude'])

# %%
df['Date']
# Out:
# 0         04-30-22
# 1         04-30-22
# 2         04-30-22
# 3         04-30-22
# 4         04-30-22
#             ...
# 128970    05-31-22
# 128971    05-31-22
# 128972    05-31-22
# 128973    05-31-22
# 128974    05-31-22
# Name: Date, Length: 128975, dtype: object

# %%
import datetime

# %%
df["year_month"] = pd.to_datetime(df["Date"]).dt.to_period('M')
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1518209387.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["year_month"] = pd.to_datetime(df["Date"]).dt.to_period('M')

# %%
df['year_month']
# Out:
# 0         2022-04
# 1         2022-04
# 2         2022-04
# 3         2022-04
# 4         2022-04
#            ...
# 128970    2022-05
# 128971    2022-05
# 128972    2022-05
# 128973    2022-05
# 128974    2022-05
# Name: year_month, Length: 128975, dtype: period[M]

# %%
monthly_sales = df.groupby('year_month')['Amount'].sum().reset_index()

# %%
monthly_sales
# Out:
#   year_month       Amount
# 0    2022-03    101683.85
# 1    2022-04  28838708.32
# 2    2022-05  26226476.75
# 3    2022-06  23425809.38

# %%
df['ship-postal-code'] = df['ship-postal-code'].fillna(0).astype(int)
df['ship-postal-code'].value_counts()
postal_df = df['ship-postal-code']
postal_df
# Out:
# 0         400081
# 1         560085
# 2         410210
# 3         605008
# 4         600073
#            ...
# 128970    500013
# 128971    122004
# 128972    500049
# 128973    389350
# 128974    492014
# Name: ship-postal-code, Length: 128975, dtype: int64

# %%
postal_df = pd.DataFrame(postal_df)
postal_df = postal_df[~postal_df['ship-postal-code'].astype(str).str[:3].eq('744')]# removing andaman postalcode as a outlier 
postal_df = postal_df[~postal_df['ship-postal-code'].astype(str).str[:3].eq('682')]# removing  Lakshadweep postalcode as a outlier 

#postal_df

# %%
postal_df[['Latitude', 'Longitude']] = postal_df['ship-postal-code'].apply(get_coordinates).apply(pd.Series)

# %%
postal_df[['Latitude', 'Longitude']] = postal_df['ship-postal-code'].apply(get_coordinates)

# %%
postal_df
# Out:
#         ship-postal-code   Latitude  Longitude
# 0                 400081  18.980800  72.833800
# 1                 560085  13.225700  77.575000
# 2                 410210  19.049800  73.070200
# 3                 605008  11.876800  79.810700
# 4                 600073  12.844667  80.095767
# ...                  ...        ...        ...
# 128970            500013  17.427440  78.468440
# 128971            122004  28.407683  76.983633
# 128972            500049  17.274350  78.444200
# 128973            389350  22.708333  73.620583
# 128974            492014  21.187900  81.689800
#
# [127661 rows x 3 columns]

# %%
# %pip install pandas geopandas matplotlib contextily
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.2 MB 2.7 MB/s eta 0:00:07
#    -- ------------------------------------- 1.3/19.2 MB 2.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.1/19.2 MB 2.7 MB/s eta 0:00:07
#    ------ --------------------------------- 3.1/19.2 MB 3.1 MB/s eta 0:00:06
#    -------- ------------------------------- 3.9/19.2 MB 3.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 5.2/19.2 MB 3.7 MB/s eta 0:00:04
#    ------------- -------------------------- 6.3/19.2 MB 3.9 MB/s eta 0:00:04
#    --------------- ------------------------ 7.6/19.2 MB 4.1 MB/s eta 0:00:03
#    ------------------ --------------------- 8.9/19.2 MB 4.4 MB/s eta 0:00:03
# ...

# %%
from shapely.geometry import Point
import geopandas as gpd

# %%
# create point geometry
geometry = [Point(xy) for xy in zip(postal_df.Longitude, postal_df.Latitude)]

# convert to geodataframe
gdf = gpd.GeoDataFrame(postal_df, crs="epsg:4326", geometry=geometry)

# %%
gdf = gdf.set_crs(epsg=4326)

# %%
gdf.plot(marker = '.', color = 'red', figsize=(40,40))
# Out:
# <Axes: >
