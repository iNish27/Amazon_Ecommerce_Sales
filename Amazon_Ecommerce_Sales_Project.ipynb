# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv(r"C:\Users\Nishs\Downloads\New Dataset\Amazon Sale Report.csv")
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_3268\3373930079.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Nishs\Downloads\New Dataset\Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# 128971            Set  ...      INR   999.0   GURUGRAM       HARYANA
# 128972  Western Dress  ...      INR   690.0  HYDERABAD     TELANGANA
# 128973            Set  ...      INR  1199.0      Halol       Gujarat
# 128974            Set  ...      INR   696.0     Raipur  CHHATTISGARH
#
#        ship-postal-code  ship-country  \
# 128970         500013.0            IN
# 128971         122004.0            IN
# 128972         500049.0            IN
# 128973         389350.0            IN
# 128974         492014.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 128970                                           NaN  False           NaN
# 128971  IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
# 128972                                           NaN  False           NaN
# 128973  IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
# 128974  IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
#
#        Unnamed: 22
# 128970       False
# 128971       False
# 128972       False
# 128973       False
# 128974       False
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %% [markdown]
# # Initiating Exploratory Data Analysis (EDA)

# %%
df.isna().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %% [markdown]
# # Removed Unnecessary Columns

# %%
df = df.drop(columns=["B2B", "Unnamed: 22"])

# %% [markdown]
# # Filling Null/Missing Values Through Average

# %%
df["Courier Status"].fillna(df["Courier Status"].mode()[0], inplace=True)

df["currency"].fillna(df["currency"].mode()[0], inplace=True)

df["Amount"].fillna(df["Amount"].mode()[0], inplace=True)

df["ship-city"].fillna(df["ship-city"].mode()[0], inplace=True)

df["ship-state"].fillna(df["ship-state"].mode()[0], inplace=True)

df["ship-postal-code"].fillna(df["ship-postal-code"].mode()[0], inplace=True)

df["ship-country"].fillna(df["ship-country"].mode()[0], inplace=True)

df["promotion-ids"].fillna(df["promotion-ids"].mode()[0], inplace=True)

df["fulfilled-by"].fillna(df["fulfilled-by"].mode()[0], inplace=True)
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Courier Status"].fillna(df["Courier Status"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["currency"].fillna(df["currency"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Amount"].fillna(df["Amount"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ship-city"].fillna(df["ship-city"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ship-state"].fillna(df["ship-state"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ship-postal-code"].fillna(df["ship-postal-code"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ship-country"].fillna(df["ship-country"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["promotion-ids"].fillna(df["promotion-ids"].mode()[0], inplace=True)
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_14592\1002119144.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["fulfilled-by"].fillna(df["fulfilled-by"].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# fulfilled-by          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Project Started ⬇️

# %% [markdown]
# ### Best Selling Categories

# %%
Best_Selling_Categories = df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
print(Best_Selling_Categories.head())
# Out:
# Category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Name: Amount, dtype: float64

# %% [markdown]
# ### Sales by Date

# %%
df["Date"] = df["Date"]
sales_Date = df.groupby("Date")["Amount"].sum()
print(sales_Date)
# Out:
# Date
# 2022-03-31     101683.85
# 2022-04-01     865478.60
# 2022-04-02     913101.53
# 2022-04-03    1011763.38
# 2022-04-04     882059.17
#                  ...
# 2022-06-25     654234.58
# 2022-06-26     773610.02
# 2022-06-27     714124.67
# 2022-06-28     772085.53
# 2022-06-29     411530.76
# Name: Amount, Length: 91, dtype: float64

# %% [markdown]
# ### Best Selling Category by City

# %%
City_Sales = df.groupby("ship-city")["Amount"].sum().sort_values(ascending=False)
print(City_Sales.head(10))
# Out:
# ship-city
# BENGALURU    7081401.99
# HYDERABAD    5132764.82
# MUMBAI       3807802.80
# NEW DELHI    3751529.78
# CHENNAI      3214854.74
# PUNE         2418318.18
# KOLKATA      1469242.87
# GURUGRAM     1255533.74
# THANE        1041861.29
# LUCKNOW       975422.34
# Name: Amount, dtype: float64

# %% [markdown]
# ### Creating Monthly Sales Bar Chart

# %%
import matplotlib.pyplot as plt
import pandas as pd

df.columns = df.columns.str.strip()
df['Date'] = pd.to_datetime(df['Date'])

monthly_sales = df.groupby(pd.Grouper(key='Date', freq='ME'))['Amount'].sum().reset_index()

plt.figure(figsize=(14, 6))
plt.bar(monthly_sales["Date"], monthly_sales["Amount"], color ='turquoise')
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_3268\506854616.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ### Creating Sales Line Plot

# %%
plt.Figure(figsize=(14, 6))
plt.plot(monthly_sales['Date'], monthly_sales['Amount'], 
         marker = 'o', linestyle = '-', color ='turquoise')
plt.title("Monthly Sales trend")
plt.xlabel("Month")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Creating Chart for Status wise Sales

# %%
status_counts = df["Status"].value_counts()

plt.figure(figsize=(8, 6))
status_counts.plot(kind = 'bar', color = 'turquoise')
plt.title("Order count by status")
plt.xlabel("Status")
plt.ylabel("Number of Orders")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pie Chart for top 10 Cities Sales wise

# %%
top_cities = df['ship-city'].value_counts().nlargest(10)

# %%
plt.Figure(figsize=(10,4))
plt.pie(top_cities,
        labels = top_cities.index,
        autopct = '%1.1f%%',
        startangle = 140,
        )

plt.title("Top 10 Shipping Cities by Order Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Creating Chart for Best Selling Categories

# %%
Best_Selling_Categories.plot(
    kind = "bar",
    figsize = (10, 5),
    color = 'turquoise',
    title = "Best Selling Categories",
    xlabel = "Category",
    ylabel = "Amount",
    )

plt.xticks(rotation = 0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top selling products by sku & style

# %%
best_selling = df.groupby("Style")["Qty"].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# ### Chart for best selling products

# %%
best_selling.plot(kind = "bar",
                  title = 'Top Selling Products (by Style)',
                  xlabel = 'Style',
                  ylabel = 'Quantity Sold',
                  color = 'Turquoise'
                  )
# Out:
# <Axes: title={'center': 'Top Selling Products (by Style)'}, xlabel='Style', ylabel='Quantity Sold'>

# %% [markdown]
# # Amount Distribution

# %%
plt.figure (figsize=(10, 5))
sns.histplot(df['Amount'], bins = 20, kde = True,color = 'Turquoise')
plt.xlabel('Amount')
plt.ylabel('Distribution')
plt.title('histplot of Amount')
plt.show()

# %% [markdown]
# # Ship-Postal-Code Distribution

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['ship-postal-code'], bins = 20, kde = True,color = 'Turquoise')
plt.xlabel('ship-postal-code')
plt.ylabel('Distribution')
plt.title('histplot of ship-postal-code')
plt.show()

# %% [markdown]
# ## Formula for Creating Box plot

# %%
Q1 = df['Amount'].quantile(0.25)
Q3 = df['Amount'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df['Amount'] = df['Amount'].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# ## Creating box plot to identify the Average Sale Amount

# %%
plt.figure(figsize= (10, 4))
sns.boxplot(x=df['Amount'], color = 'Turquoise')
plt.xlabel('Amount')
plt.title('Boxplot of Amount')
plt.show()

# %% [markdown]
# # Creating Violinplot to show distribution and density

# %%
plt.figure(figsize=(10, 4))
sns.violinplot(x=df["Amount"], color='Turquoise')
plt.title("Violin Plot of Amount")
plt.xlabel("Amount")
plt.show()

# %% [markdown]
# # Density plot to show density of amount

# %%
plt.figure(figsize = (10, 4))
sns.kdeplot(df['Amount'], fill = True, color = 'Turquoise')
plt.title('Density plot of Amount')
plt.xlabel('Amount')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# # Creating Density plot to determine the Ship-Postal-Code density

# %%
plt.Figure(figsize=(10, 4))
sns.kdeplot(df['ship-postal-code'], fill = True, color = 'Turquoise')
plt.title("Density plot of Amount")
plt.xlabel("ship-postal-code")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Creating Histogram Plot to analyze distribution of amount according to category

# %%
plt.Figure(figsize=(10, 4))
sns.histplot(data=df, x = 'Amount', hue='Category', bins = 20, kde=True, palette = 'viridis')
plt.title('Histogram of Amount by Category')
plt.xlabel('Amount')
plt.ylabel('Count')
plt.legend(title = 'Category')
plt.show()
# Out:
# C:\Users\Nishs\AppData\Local\Temp\ipykernel_3268\1907935732.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title = 'Category')

# %% [markdown]
# # Creating Heatmap Chart to analyze Correlations

# %%
numeric_df = df.select_dtypes(include = ['number'])
corr = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot = True, cmap = 'RdBu', fmt=".2f", linewidths=0.5)
plt.title("Heatmap of Numerical Features", fontsize="20")
plt.show()

# %% [markdown]
# # Installing & Importing Geocode library to illustrate the most shipping postal codes in India

# %%
# %pip install pgeocode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pgeocode in c:\users\nishs\appdata\roaming\python\python313\site-packages (0.5.0)
# Requirement already satisfied: requests in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pgeocode) (2.32.3)
# Requirement already satisfied: numpy in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pgeocode) (2.2.6)
# Requirement already satisfied: pandas in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pgeocode) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas->pgeocode) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas->pgeocode) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas->pgeocode) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->pgeocode) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->pgeocode) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->pgeocode) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->pgeocode) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->pgeocode) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pgeocode

# %% [markdown]
# # Initialize pgeocode for India

# %%
pgeocode = pgeocode.Nominatim('IN')

# %%
# function to get coordinates

def get_coordinates(postal_code):
    try:
        results = pgeocode.query_postal_code(postal_code)
        return pd.Series([results.latitude, results.longitude], index=['latitude', 'longitude'])
    except Exception as e:
        print(f'Error for postal code {postal_code}: {e}')
        return pd.Series([None, None], index=['latitude', 'longitude'])

# %%
df['ship-postal-code'] = df['ship-postal-code'].fillna(0).astype(int)
df['ship-postal-code'].value_counts()
postal_df = df['ship-postal-code']
postal_df
# Out:
# 0         400081
# 1         560085
# 2         410210
# 3         605008
# 4         600073
#            ...
# 128970    500013
# 128971    122004
# 128972    500049
# 128973    389350
# 128974    492014
# Name: ship-postal-code, Length: 128975, dtype: int64

# %%
postal_df = pd.DataFrame(postal_df)
postal_df = postal_df[~postal_df['ship-postal-code'].astype(str).str[:3].eq('744')]# removing andaman postalcode as a outlier 
postal_df = postal_df[~postal_df['ship-postal-code'].astype(str).str[:3].eq('682')]# removing  Lakshadweep postalcode as a outlier 

postal_df

# %%
postal_df[['Latitude', 'Longitude']] = postal_df['ship-postal-code'].apply(get_coordinates).apply(pd.Series)

# %%
postal_df[['Latitude', 'Longitude']] = postal_df['ship-postal-code'].apply(get_coordinates)

# %%
postal_df
# Out:
#         ship-postal-code Latitude Longitude
# 0                 400081     None      None
# 1                 560085     None      None
# 2                 410210     None      None
# 3                 605008     None      None
# 4                 600073     None      None
# ...                  ...      ...       ...
# 128970            500013     None      None
# 128971            122004     None      None
# 128972            500049     None      None
# 128973            389350     None      None
# 128974            492014     None      None
#
# [127661 rows x 3 columns]

# %% [markdown]
# # Installing & Importing Geopandas for plotting the Ship-Postal-Codes on Map of India

# %%
# %pip install pandas geopandas matplotlib contextily
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\nishs\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: geopandas in c:\users\nishs\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\nishs\appdata\roaming\python\python313\site-packages (3.10.3)
# Requirement already satisfied: contextily in c:\users\nishs\appdata\roaming\python\python313\site-packages (1.6.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in c:\users\nishs\appdata\roaming\python\python313\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: geopy in c:\users\nishs\appdata\roaming\python\python313\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: mercantile in c:\users\nishs\appdata\roaming\python\python313\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: rasterio in c:\users\nishs\appdata\roaming\python\python313\site-packages (from contextily) (1.4.3)
# Requirement already satisfied: requests in c:\users\nishs\appdata\roaming\python\python313\site-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in c:\users\nishs\appdata\roaming\python\python313\site-packages (from contextily) (1.5.1)
# Requirement already satisfied: xyzservices in c:\users\nishs\appdata\roaming\python\python313\site-packages (from contextily) (2025.4.0)
# Requirement already satisfied: certifi in c:\users\nishs\appdata\roaming\python\python313\site-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: click>=3.0 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from mercantile->contextily) (8.2.1)
# Requirement already satisfied: affine in c:\users\nishs\appdata\roaming\python\python313\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in c:\users\nishs\appdata\roaming\python\python313\site-packages (from rasterio->contextily) (25.3.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\nishs\appdata\roaming\python\python313\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->contextily) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nishs\appdata\roaming\python\python313\site-packages (from requests->contextily) (2.4.0)
# Requirement already satisfied: colorama in c:\users\nishs\appdata\roaming\python\python313\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from shapely.geometry import Point
import geopandas as gpd

# %%
postal_df[["Latitude", "Longitude"]].isnull().sum()
# Out:
# Latitude     1159
# Longitude    1159
# dtype: int64

# %%
# create point geometry
geometry = [Point(xy) for xy in zip(postal_df.Longitude, postal_df.Latitude)]

# convert to geodataframe
gdf = gpd.GeoDataFrame(postal_df, crs="epsg:4326", geometry=geometry)

# %%
gdf = gdf.set_crs(epsg=4326)

# %%
gdf.plot(marker = '.', color = 'turquoise', figsize=(40,40))
# Out:
# <Axes: >
